# %% [markdown]
# <a href="https://colab.research.google.com/github/dineshkumarsarangapani/stablediffusion/blob/main/Stable_diffusion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install accelerate

# %%
# !pip install git+https://github.com/huggingface/diffusers
# Out:
# ...
#   Cloning https://github.com/huggingface/diffusers to /tmp/pip-req-build-jtv3fgcq
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/diffusers /tmp/pip-req-build-jtv3fgcq
#   Resolved https://github.com/huggingface/diffusers to commit ea1fcc28a458739771f5112767f70d281511d2a2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for diffusers: filename=diffusers-0.20.0.dev0-py3-none-any.whl size=1326731 sha256=07fb06de83016c9cd3edfd1838d5e73f31bc4033e15d8547c6d76722b3e639c0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-iei5f8cm/wheels/f7/7d/99/d361489e5762e3464b3811bc629e94cf5bf5ef44dd5c3c4d52
# Successfully built diffusers
# ...
#   Attempting uninstall: diffusers
#     Found existing installation: diffusers 0.19.3
#     Uninstalling diffusers-0.19.3:
#       Successfully uninstalled diffusers-0.19.3
# ...

# %%
import torch
from diffusers import DiffusionPipeline

model_id = "runwayml/stable-diffusion-v1-5"

pipeline = DiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipeline = pipeline.to("cuda")
generator = torch.Generator("cuda").manual_seed(0)
image = pipeline("A indian man in a Tiger", generator=generator).images[0]
image
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# ...
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["bos_token_id"]` will be overriden.
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["eos_token_id"]` will be overriden.
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %% [markdown]
# https://huggingface.co/docs/diffusers/stable_diffusion

# %%
image = pipeline("A Tamil indian Girl", generator=generator).images[0]
image
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
image = pipeline("A Tamil indian women", generator=generator).images[0]
image
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
image = pipeline("A dragon flying towards the moon", generator=generator).images[0]
image
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
image = pipeline("(RAW photo, best quality), 8k UHD, DSLR finely detail, ultra-detailed, highres thor vs hulk, fighting, second-person view",negative_prompt="badhandv4, easynegative, ng_deepnegative_v1_75t, by_bad_artist-neg, (deformed, distorted, disfigured:1.3), poorly drawn, bad anatomy, wrong anatomy, extra limb, missing limb, floating limbs, (mutated hands and fingers:1.4), disconnected limbs, mutation, mutated, ugly, disgusting, blurry, amputation",  generator=generator).images[0]
image
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
